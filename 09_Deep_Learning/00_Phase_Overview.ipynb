# %% [markdown]
# # Phase 9: Deep Learning
#
# ## Phase goal
#
# Understand and implement neural networks, CNNs, sequence models, attention, and transformers with disciplined training practices.
#
# **Estimated lesson time:** 28.1 hours
# **Recommended additional practice:** 19 hours
# **Prerequisite:** Python, NumPy, basic linear algebra/calculus, and ML evaluation.
#
# This phase progresses from conceptual foundations to practitioner execution and advanced failure analysis. Complete lessons in order unless a diagnostic assessment shows that you already satisfy the readiness criteria.

# %% [markdown]
# ## Phase learning outcomes
#
# After completing this phase, you should be able to:
#
# 1. Explain every central concept without relying on library vocabulary alone.
# 2. Implement the core mechanisms in small, testable examples.
# 3. Select methods according to assumptions, constraints, and decision cost.
# 4. Detect common correctness, leakage, interpretation, and operational failures.
# 5. Complete the phase lab without copying the reference solution.
# 6. Produce the phase project with evidence, tests, limitations, and a professional handoff.

# %% [markdown]
# ## Notebook sequence
#
#         | # | Notebook | Level | Suggested time | Purpose |
#         |---:|---|---|---:|---|
#         | 01 | [PyTorch Tensors, Devices, and Autograd](01_PyTorch_Tensors_Devices_and_Autograd.ipynb) | Foundation | 105 min | Move from NumPy arrays to differentiable tensors and understand shape, dtype, device, computation graphs, and gradients. |
# | 02 | [Neurons, Activations, Outputs, and Losses](02_Neurons_Activations_Outputs_and_Losses.ipynb) | Foundation | 120 min | Understand affine layers, nonlinear activations, logits, probabilities, and task-appropriate loss functions. |
# | 03 | [Backpropagation from First Principles](03_Backpropagation_from_First_Principles.ipynb) | Practitioner | 135 min | Trace local derivatives through a computation graph and connect manual chain rule to automatic differentiation. |
# | 04 | [Datasets, DataLoaders, Training Loops, and Optimizers](04_Datasets_DataLoaders_Training_Loops_and_Optimizers.ipynb) | Practitioner | 145 min | Implement the full optimization loop with batches, modes, gradient reset, validation, checkpoints, and optimizer state. |
# | 05 | [Feed-Forward Networks for Tabular Data](05_Feed_Forward_Networks_for_Tabular_Data.ipynb) | Practitioner | 140 min | Build multilayer perceptrons and compare their inductive bias with tree ensembles and linear baselines. |
# | 06 | [Initialization, Normalization, Dropout, Schedules, and Early Stopping](06_Initialization_Normalization_Dropout_Schedules_and_Early_Stopping.ipynb) | Advanced | 140 min | Stabilize optimization and generalization with principled initialization, normalization, regularization, and validation controls. |
# | 07 | [Convolutional Neural Networks](07_Convolutional_Neural_Networks.ipynb) | Practitioner | 160 min | Learn spatially shared filters, receptive fields, padding, stride, pooling, channel growth, and image augmentation. |
# | 08 | [Transfer Learning and Fine-Tuning](08_Transfer_Learning_and_Fine_Tuning.ipynb) | Advanced | 120 min | Adapt pretrained representations by replacing heads, freezing layers, controlling learning rates, and avoiding domain mismatch. |
# | 09 | [RNNs, LSTMs, and GRUs](09_RNNs_LSTMs_and_GRUs.ipynb) | Advanced | 150 min | Model ordered sequences with recurrent state and understand gating, truncation, padding, and long-range dependency limitations. |
# | 10 | [Attention from First Principles](10_Attention_from_First_Principles.ipynb) | Advanced | 155 min | Compute query-key compatibility, normalized attention weights, value aggregation, masks, and multi-head specialization. |
# | 11 | [Transformer Encoders and Text Classification](11_Transformer_Encoders_and_Text_Classification.ipynb) | Advanced | 165 min | Compose embeddings, positions, self-attention, feed-forward blocks, residuals, normalization, pooling, and classification heads. |
# | 12 | [Deep-Learning Debugging, Evaluation, Reproducibility, and Serving](12_Deep_Learning_Debugging_Evaluation_Reproducibility_and_Serving.ipynb) | Advanced | 150 min | Diagnose data, shape, gradient, optimization, overfitting, calibration, latency, and reproducibility failures. |
#
#         ### Dependency path
#
#         1. **PyTorch Tensors, Devices, and Autograd** — builds the concepts needed for **Neurons, Activations, Outputs, and Losses**.
# 2. **Neurons, Activations, Outputs, and Losses** — builds the concepts needed for **Backpropagation from First Principles**.
# 3. **Backpropagation from First Principles** — builds the concepts needed for **Datasets, DataLoaders, Training Loops, and Optimizers**.
# 4. **Datasets, DataLoaders, Training Loops, and Optimizers** — builds the concepts needed for **Feed-Forward Networks for Tabular Data**.
# 5. **Feed-Forward Networks for Tabular Data** — builds the concepts needed for **Initialization, Normalization, Dropout, Schedules, and Early Stopping**.
# 6. **Initialization, Normalization, Dropout, Schedules, and Early Stopping** — builds the concepts needed for **Convolutional Neural Networks**.
# 7. **Convolutional Neural Networks** — builds the concepts needed for **Transfer Learning and Fine-Tuning**.
# 8. **Transfer Learning and Fine-Tuning** — builds the concepts needed for **RNNs, LSTMs, and GRUs**.
# 9. **RNNs, LSTMs, and GRUs** — builds the concepts needed for **Attention from First Principles**.
# 10. **Attention from First Principles** — builds the concepts needed for **Transformer Encoders and Text Classification**.
# 11. **Transformer Encoders and Text Classification** — builds the concepts needed for **Deep-Learning Debugging, Evaluation, Reproducibility, and Serving**.
# 12. **Deep-Learning Debugging, Evaluation, Reproducibility, and Serving** — builds the concepts needed for the phase lab and project.

# %% [markdown]
# ## How to study this phase
#
# Use a three-pass method:
#
# ### Pass 1 — Understand
# Read the mental model, vocabulary, and formal lens. Run the example only after predicting its result.
#
# ### Pass 2 — Reconstruct
# Close the example and recreate the mechanism in a fresh cell or file. Use assertions and edge cases.
#
# ### Pass 3 — Transfer
# Apply the method to a bundled dataset or a new scenario. Explain assumptions, limitations, and decision impact.
#
# A suggested cadence is **five hours per week for approximately 6 week(s)** for the core lessons, followed by the lab, assessment, and project.

# %% [markdown]
# ## Phase lab
#
#         **Scenario:** A research team needs reproducible neural baselines for tabular and image tasks before considering larger architectures.
#
#         **Deliverable:** A training notebook with shape checks, tiny-batch overfit test, baseline comparison, checkpoints, and error analysis.
#
#         Required work:
#
#         - Specify tensor shapes and task losses.
# - Create deterministic train/validation/test partitions.
# - Implement correct training/evaluation loops.
# - Overfit a tiny batch as a pipeline test.
# - Train an MLP and CNN with early-stopping logic.
# - Inspect gradients and class-wise errors.
# - Record reproducibility and serving requirements.
#
#         Files:
#
#         - `../exercises/Phase_09_Lab.ipynb`
#         - `../solutions/Phase_09_Lab_Solution.ipynb`
#         - `../assessments/Phase_09_Assessment.ipynb`

# %% [markdown]
# ## Phase project
#
# **Multi-Modal Deep Learning Portfolio**
#
# Train and evaluate tabular, image, and sequence models, then document debugging, reproducibility, and deployment constraints.
#
# The formal project brief is in:
#
# `../projects/Phase_09_Multi_Modal_Deep_Learning_Portfolio.ipynb`
#
# ### Minimum professional standard
#
# - reproducible environment and random state;
# - explicit input/output contracts;
# - tests or validation assertions;
# - clear assumptions and excluded uses;
# - evidence-backed conclusions;
# - limitations and risk register;
# - README-style run instructions;
# - no hidden notebook state.

# %% [markdown]
# ## Readiness checkpoint
#
# Proceed to the next phase only when you can:
#
# - [ ] explain the phase goal and how each lesson contributes;
# - [ ] run every required notebook from a clean kernel;
# - [ ] complete at least 70% of independent exercises;
# - [ ] score at least 80% on the phase assessment;
# - [ ] complete the lab before reading its solution;
# - [ ] produce the phase project and self-score it with the rubric;
# - [ ] name three failure modes you would watch for in real work.
