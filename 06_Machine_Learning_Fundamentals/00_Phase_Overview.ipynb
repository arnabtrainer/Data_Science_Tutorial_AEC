# %% [markdown]
# # Phase 6: Machine Learning Fundamentals
#
# ## Phase goal
#
# Design trustworthy ML experiments with correct splits, pipelines, metrics, validation, and decision thresholds.
#
# **Estimated lesson time:** 16.5 hours
# **Recommended additional practice:** 11 hours
# **Prerequisite:** Phases 1–5, especially data quality, statistics, and EDA.
#
# This phase progresses from conceptual foundations to practitioner execution and advanced failure analysis. Complete lessons in order unless a diagnostic assessment shows that you already satisfy the readiness criteria.

# %% [markdown]
# ## Phase learning outcomes
#
# After completing this phase, you should be able to:
#
# 1. Explain every central concept without relying on library vocabulary alone.
# 2. Implement the core mechanisms in small, testable examples.
# 3. Select methods according to assumptions, constraints, and decision cost.
# 4. Detect common correctness, leakage, interpretation, and operational failures.
# 5. Complete the phase lab without copying the reference solution.
# 6. Produce the phase project with evidence, tests, limitations, and a professional handoff.

# %% [markdown]
# ## Notebook sequence
#
#         | # | Notebook | Level | Suggested time | Purpose |
#         |---:|---|---|---:|---|
#         | 01 | [Problem Formulation and Baseline Models](01_Problem_Formulation_and_Baseline_Models.ipynb) | Foundation | 100 min | Define the prediction unit, action, horizon, loss, constraint, and minimum baseline that a learned model must beat. |
# | 02 | [Train, Validation, Test, Group, and Time Splits](02_Train_Validation_Test_Group_and_Time_Splits.ipynb) | Foundation | 115 min | Choose a split that imitates deployment and prevents identity, group, temporal, or preprocessing leakage. |
# | 03 | [Imputation, Encoding, Scaling, and Feature Engineering](03_Imputation_Encoding_Scaling_and_Feature_Engineering.ipynb) | Practitioner | 125 min | Learn transformations only from training data, handle unknown categories, and build features whose availability is reproducible at inference. |
# | 04 | [Scikit-learn Estimators, Pipelines, and ColumnTransformer](04_Scikit_learn_Estimators_Pipelines_and_ColumnTransformer.ipynb) | Practitioner | 120 min | Compose preprocessing and estimation into one fitted object that preserves ordering, reproducibility, and train-serving parity. |
# | 05 | [Regression and Classification Metrics](05_Regression_and_Classification_Metrics.ipynb) | Practitioner | 135 min | Select metrics that reflect error cost, prevalence, ranking, probability quality, and operational constraints. |
# | 06 | [Underfitting, Overfitting, Bias-Variance, and Regularization](06_Underfitting_Overfitting_Bias_Variance_and_Regularization.ipynb) | Practitioner | 120 min | Diagnose capacity and data limitations using learning curves, validation gaps, regularization, and error decomposition. |
# | 07 | [Cross-Validation and Hyperparameter Search](07_Cross_Validation_and_Hyperparameter_Search.ipynb) | Advanced | 130 min | Estimate model-selection performance without leaking the test set and search efficiently over meaningful parameter ranges. |
# | 08 | [Imbalance, Thresholds, Calibration, and Error Analysis](08_Imbalance_Thresholds_Calibration_and_Error_Analysis.ipynb) | Advanced | 145 min | Separate ranking from decision policy, choose thresholds under constraints, calibrate probabilities, and inspect failures by meaningful slices. |
#
#         ### Dependency path
#
#         1. **Problem Formulation and Baseline Models** — builds the concepts needed for **Train, Validation, Test, Group, and Time Splits**.
# 2. **Train, Validation, Test, Group, and Time Splits** — builds the concepts needed for **Imputation, Encoding, Scaling, and Feature Engineering**.
# 3. **Imputation, Encoding, Scaling, and Feature Engineering** — builds the concepts needed for **Scikit-learn Estimators, Pipelines, and ColumnTransformer**.
# 4. **Scikit-learn Estimators, Pipelines, and ColumnTransformer** — builds the concepts needed for **Regression and Classification Metrics**.
# 5. **Regression and Classification Metrics** — builds the concepts needed for **Underfitting, Overfitting, Bias-Variance, and Regularization**.
# 6. **Underfitting, Overfitting, Bias-Variance, and Regularization** — builds the concepts needed for **Cross-Validation and Hyperparameter Search**.
# 7. **Cross-Validation and Hyperparameter Search** — builds the concepts needed for **Imbalance, Thresholds, Calibration, and Error Analysis**.
# 8. **Imbalance, Thresholds, Calibration, and Error Analysis** — builds the concepts needed for the phase lab and project.

# %% [markdown]
# ## How to study this phase
#
# Use a three-pass method:
#
# ### Pass 1 — Understand
# Read the mental model, vocabulary, and formal lens. Run the example only after predicting its result.
#
# ### Pass 2 — Reconstruct
# Close the example and recreate the mechanism in a fresh cell or file. Use assertions and edge cases.
#
# ### Pass 3 — Transfer
# Apply the method to a bundled dataset or a new scenario. Explain assumptions, limitations, and decision impact.
#
# A suggested cadence is **five hours per week for approximately 4 week(s)** for the core lessons, followed by the lab, assessment, and project.

# %% [markdown]
# ## Phase lab
#
#         **Scenario:** A team needs a leakage-safe baseline for churn prioritization under a fixed outreach capacity.
#
#         **Deliverable:** A reproducible model pipeline with baseline comparison, cross-validation, threshold policy, calibration check, and error slices.
#
#         Required work:
#
#         - Create a deployment-like split and preserve a final holdout.
# - Establish dummy and simple linear baselines.
# - Put imputation, encoding, and scaling inside a pipeline.
# - Cross-validate using metrics appropriate for imbalance.
# - Choose a threshold under an outreach-capacity or recall constraint.
# - Inspect calibration and subgroup error rates.
# - Document reproducibility metadata.
#
#         Files:
#
#         - `../exercises/Phase_06_Lab.ipynb`
#         - `../solutions/Phase_06_Lab_Solution.ipynb`
#         - `../assessments/Phase_06_Assessment.ipynb`

# %% [markdown]
# ## Phase project
#
# **Leakage-Safe Baseline Pipeline**
#
# Build and compare reproducible baseline models using a complete preprocessing pipeline and defensible evaluation protocol.
#
# The formal project brief is in:
#
# `../projects/Phase_06_Leakage_Safe_Baseline_Pipeline.ipynb`
#
# ### Minimum professional standard
#
# - reproducible environment and random state;
# - explicit input/output contracts;
# - tests or validation assertions;
# - clear assumptions and excluded uses;
# - evidence-backed conclusions;
# - limitations and risk register;
# - README-style run instructions;
# - no hidden notebook state.

# %% [markdown]
# ## Readiness checkpoint
#
# Proceed to the next phase only when you can:
#
# - [ ] explain the phase goal and how each lesson contributes;
# - [ ] run every required notebook from a clean kernel;
# - [ ] complete at least 70% of independent exercises;
# - [ ] score at least 80% on the phase assessment;
# - [ ] complete the lab before reading its solution;
# - [ ] produce the phase project and self-score it with the rubric;
# - [ ] name three failure modes you would watch for in real work.
