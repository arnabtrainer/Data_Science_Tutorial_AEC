# %% [markdown]
# # Phase 2: NumPy and Pandas
#
# ## Phase goal
#
# Manipulate numerical and tabular data correctly, efficiently, and reproducibly.
#
# **Estimated lesson time:** 14.2 hours
# **Recommended additional practice:** 10 hours
# **Prerequisite:** Complete Phase 1 or be comfortable with functions, collections, files, and exceptions.
#
# This phase progresses from conceptual foundations to practitioner execution and advanced failure analysis. Complete lessons in order unless a diagnostic assessment shows that you already satisfy the readiness criteria.

# %% [markdown]
# ## Phase learning outcomes
#
# After completing this phase, you should be able to:
#
# 1. Explain every central concept without relying on library vocabulary alone.
# 2. Implement the core mechanisms in small, testable examples.
# 3. Select methods according to assumptions, constraints, and decision cost.
# 4. Detect common correctness, leakage, interpretation, and operational failures.
# 5. Complete the phase lab without copying the reference solution.
# 6. Produce the phase project with evidence, tests, limitations, and a professional handoff.

# %% [markdown]
# ## Notebook sequence
#
#         | # | Notebook | Level | Suggested time | Purpose |
#         |---:|---|---|---:|---|
#         | 01 | [NumPy Arrays, Shape, Dtypes, and Memory](01_NumPy_Arrays_Shape_Dtypes_and_Memory.ipynb) | Foundation | 90 min | Understand ndarray structure, dimensionality, dtypes, strides, views, copies, and memory cost. |
# | 02 | [Indexing, Masking, Vectorization, and Broadcasting](02_Indexing_Masking_Vectorization_and_Broadcasting.ipynb) | Practitioner | 105 min | Replace slow element-wise Python loops with array operations and reason about compatible shapes. |
# | 03 | [Aggregation, Randomness, Linear Algebra, and Performance](03_Aggregation_Randomness_Linear_Algebra_and_Performance.ipynb) | Advanced | 110 min | Use reductions, reproducible generators, matrix operations, stable linear solvers, and performance-aware numerical patterns. |
# | 04 | [Pandas Series, DataFrames, and Data Input](04_Pandas_Series_DataFrames_and_Data_Input.ipynb) | Foundation | 95 min | Load data deliberately and understand labels, indexes, dtypes, schema inspection, and tabular semantics. |
# | 05 | [Selection, Filtering, Sorting, and Transformation](05_Selection_Filtering_Sorting_and_Transformation.ipynb) | Practitioner | 100 min | Select by label or position, combine conditions correctly, derive columns, chain operations, and preserve intent. |
# | 06 | [Missing Values, Duplicates, Strings, and Categories](06_Missing_Values_Duplicates_Strings_and_Categories.ipynb) | Practitioner | 115 min | Treat data defects according to meaning rather than applying indiscriminate deletion or imputation. |
# | 07 | [GroupBy, Aggregation, Pivoting, Merging, and Reshaping](07_GroupBy_Aggregation_Pivoting_Merging_and_Reshaping.ipynb) | Practitioner | 120 min | Move between transaction-level and analytical grains while validating joins and aggregations. |
# | 08 | [Dates, Time Series, Rolling Windows, and Performance](08_Dates_Time_Series_Rolling_Windows_and_Performance.ipynb) | Advanced | 120 min | Work with temporal indexes, lags, resampling, rolling windows, time zones, and efficient columnar operations. |
#
#         ### Dependency path
#
#         1. **NumPy Arrays, Shape, Dtypes, and Memory** — builds the concepts needed for **Indexing, Masking, Vectorization, and Broadcasting**.
# 2. **Indexing, Masking, Vectorization, and Broadcasting** — builds the concepts needed for **Aggregation, Randomness, Linear Algebra, and Performance**.
# 3. **Aggregation, Randomness, Linear Algebra, and Performance** — builds the concepts needed for **Pandas Series, DataFrames, and Data Input**.
# 4. **Pandas Series, DataFrames, and Data Input** — builds the concepts needed for **Selection, Filtering, Sorting, and Transformation**.
# 5. **Selection, Filtering, Sorting, and Transformation** — builds the concepts needed for **Missing Values, Duplicates, Strings, and Categories**.
# 6. **Missing Values, Duplicates, Strings, and Categories** — builds the concepts needed for **GroupBy, Aggregation, Pivoting, Merging, and Reshaping**.
# 7. **GroupBy, Aggregation, Pivoting, Merging, and Reshaping** — builds the concepts needed for **Dates, Time Series, Rolling Windows, and Performance**.
# 8. **Dates, Time Series, Rolling Windows, and Performance** — builds the concepts needed for the phase lab and project.

# %% [markdown]
# ## How to study this phase
#
# Use a three-pass method:
#
# ### Pass 1 — Understand
# Read the mental model, vocabulary, and formal lens. Run the example only after predicting its result.
#
# ### Pass 2 — Reconstruct
# Close the example and recreate the mechanism in a fresh cell or file. Use assertions and edge cases.
#
# ### Pass 3 — Transfer
# Apply the method to a bundled dataset or a new scenario. Explain assumptions, limitations, and decision impact.
#
# A suggested cadence is **five hours per week for approximately 3 week(s)** for the core lessons, followed by the lab, assessment, and project.

# %% [markdown]
# ## Phase lab
#
#         **Scenario:** A monthly retail extract must be converted from messy transactions into a trusted analytical table.
#
#         **Deliverable:** A reproducible cleaning and aggregation pipeline plus a machine-readable quality report.
#
#         Required work:
#
#         - Declare expected columns, types, value ranges, and key uniqueness.
# - Parse dates with explicit invalid handling.
# - Standardize category and region text.
# - Resolve duplicates under a documented key.
# - Treat missing and impossible numeric values using a justified rule.
# - Create monthly/category summaries and validate totals.
# - Export cleaned data and a quality report.
#
#         Files:
#
#         - `../exercises/Phase_02_Lab.ipynb`
#         - `../solutions/Phase_02_Lab_Solution.ipynb`
#         - `../assessments/Phase_02_Assessment.ipynb`

# %% [markdown]
# ## Phase project
#
# **Retail Data Preparation Pipeline**
#
# Audit, clean, combine, reshape, and summarize raw retail data while preserving an explicit data-quality report.
#
# The formal project brief is in:
#
# `../projects/Phase_02_Retail_Data_Preparation_Pipeline.ipynb`
#
# ### Minimum professional standard
#
# - reproducible environment and random state;
# - explicit input/output contracts;
# - tests or validation assertions;
# - clear assumptions and excluded uses;
# - evidence-backed conclusions;
# - limitations and risk register;
# - README-style run instructions;
# - no hidden notebook state.

# %% [markdown]
# ## Readiness checkpoint
#
# Proceed to the next phase only when you can:
#
# - [ ] explain the phase goal and how each lesson contributes;
# - [ ] run every required notebook from a clean kernel;
# - [ ] complete at least 70% of independent exercises;
# - [ ] score at least 80% on the phase assessment;
# - [ ] complete the lab before reading its solution;
# - [ ] produce the phase project and self-score it with the rubric;
# - [ ] name three failure modes you would watch for in real work.
