# %% [markdown]
# # Phase 1: Python Foundation
#
# ## Phase goal
#
# Build reliable Python fluency, from expressions and collections to testing, typing, object design, and reusable packages.
#
# **Estimated lesson time:** 14.2 hours
# **Recommended additional practice:** 10 hours
# **Prerequisite:** No prior programming experience is assumed.
#
# This phase progresses from conceptual foundations to practitioner execution and advanced failure analysis. Complete lessons in order unless a diagnostic assessment shows that you already satisfy the readiness criteria.

# %% [markdown]
# ## Phase learning outcomes
#
# After completing this phase, you should be able to:
#
# 1. Explain every central concept without relying on library vocabulary alone.
# 2. Implement the core mechanisms in small, testable examples.
# 3. Select methods according to assumptions, constraints, and decision cost.
# 4. Detect common correctness, leakage, interpretation, and operational failures.
# 5. Complete the phase lab without copying the reference solution.
# 6. Produce the phase project with evidence, tests, limitations, and a professional handoff.

# %% [markdown]
# ## Notebook sequence
#
#         | # | Notebook | Level | Suggested time | Purpose |
#         |---:|---|---|---:|---|
#         | 01 | [Python, Jupyter, Variables, and Types](01_Python_Jupyter_Variables_and_Types.ipynb) | Foundation | 75 min | Learn how Python evaluates expressions, stores references, distinguishes mutable from immutable objects, and executes notebook cells. |
# | 02 | [Strings and Core Collections](02_Strings_and_Core_Collections.ipynb) | Foundation | 90 min | Use strings, lists, tuples, sets, and dictionaries according to their semantic and performance characteristics. |
# | 03 | [Control Flow and Iteration](03_Control_Flow_and_Iteration.ipynb) | Foundation | 75 min | Express decisions and repetition clearly using conditions, loops, iteration protocols, and validation guards. |
# | 04 | [Functions, Scope, and Comprehensions](04_Functions_Scope_and_Comprehensions.ipynb) | Foundation | 100 min | Design small functions with explicit contracts, predictable scope, composable return values, and readable comprehensions. |
# | 05 | [Files, Paths, CSV, and JSON](05_Files_Paths_CSV_and_JSON.ipynb) | Foundation | 90 min | Read and write structured data safely with context managers, explicit encodings, and portable paths. |
# | 06 | [Exceptions, Debugging, and Logging](06_Exceptions_Debugging_and_Logging.ipynb) | Practitioner | 90 min | Separate expected failure handling from programmer errors and preserve diagnostic evidence with structured logs. |
# | 07 | [Object-Oriented Design and Data Classes](07_Object_Oriented_Design_and_Data_Classes.ipynb) | Practitioner | 105 min | Model state and behaviour with classes while preferring cohesion, composition, invariants, and simple data classes. |
# | 08 | [Iterators, Generators, Decorators, and Context Managers](08_Iterators_Generators_Decorators_and_Context_Managers.ipynb) | Advanced | 110 min | Build lazy pipelines and reusable control-flow abstractions without obscuring ownership or lifecycle. |
# | 09 | [Typing, Testing, Clean Code, and Packaging](09_Typing_Testing_Clean_Code_and_Packaging.ipynb) | Advanced | 120 min | Move from scripts to maintainable software using type hints, unit tests, dependency boundaries, documentation, and package structure. |
#
#         ### Dependency path
#
#         1. **Python, Jupyter, Variables, and Types** — builds the concepts needed for **Strings and Core Collections**.
# 2. **Strings and Core Collections** — builds the concepts needed for **Control Flow and Iteration**.
# 3. **Control Flow and Iteration** — builds the concepts needed for **Functions, Scope, and Comprehensions**.
# 4. **Functions, Scope, and Comprehensions** — builds the concepts needed for **Files, Paths, CSV, and JSON**.
# 5. **Files, Paths, CSV, and JSON** — builds the concepts needed for **Exceptions, Debugging, and Logging**.
# 6. **Exceptions, Debugging, and Logging** — builds the concepts needed for **Object-Oriented Design and Data Classes**.
# 7. **Object-Oriented Design and Data Classes** — builds the concepts needed for **Iterators, Generators, Decorators, and Context Managers**.
# 8. **Iterators, Generators, Decorators, and Context Managers** — builds the concepts needed for **Typing, Testing, Clean Code, and Packaging**.
# 9. **Typing, Testing, Clean Code, and Packaging** — builds the concepts needed for the phase lab and project.

# %% [markdown]
# ## How to study this phase
#
# Use a three-pass method:
#
# ### Pass 1 — Understand
# Read the mental model, vocabulary, and formal lens. Run the example only after predicting its result.
#
# ### Pass 2 — Reconstruct
# Close the example and recreate the mechanism in a fresh cell or file. Use assertions and edge cases.
#
# ### Pass 3 — Transfer
# Apply the method to a bundled dataset or a new scenario. Explain assumptions, limitations, and decision impact.
#
# A suggested cadence is **five hours per week for approximately 3 week(s)** for the core lessons, followed by the lab, assessment, and project.

# %% [markdown]
# ## Phase lab
#
#         **Scenario:** A training organization receives learner records from JSON and CSV. Some rows are incomplete, duplicated, or invalid.
#
#         **Deliverable:** A small Python package-style processor that validates records, calculates per-learner summaries, logs rejected records, writes a clean CSV, and includes tests.
#
#         Required work:
#
#         - Define a `LearnerRecord` data class with validation rules.
# - Load records using `pathlib` and a context manager.
# - Normalize names and score types without silently accepting impossible scores.
# - Deduplicate by learner ID with an explicit policy.
# - Calculate count, mean, minimum, maximum, and pass status.
# - Write accepted and rejected outputs separately.
# - Add unit tests for normal, boundary, empty, and invalid cases.
#
#         Files:
#
#         - `../exercises/Phase_01_Lab.ipynb`
#         - `../solutions/Phase_01_Lab_Solution.ipynb`
#         - `../assessments/Phase_01_Assessment.ipynb`

# %% [markdown]
# ## Phase project
#
# **Validated Learning-Record Processor**
#
# Read JSON/CSV learning records, validate them, calculate summaries, log rejected rows, and expose a clean object-oriented API with tests.
#
# The formal project brief is in:
#
# `../projects/Phase_01_Validated_Learning_Record_Processor.ipynb`
#
# ### Minimum professional standard
#
# - reproducible environment and random state;
# - explicit input/output contracts;
# - tests or validation assertions;
# - clear assumptions and excluded uses;
# - evidence-backed conclusions;
# - limitations and risk register;
# - README-style run instructions;
# - no hidden notebook state.

# %% [markdown]
# ## Readiness checkpoint
#
# Proceed to the next phase only when you can:
#
# - [ ] explain the phase goal and how each lesson contributes;
# - [ ] run every required notebook from a clean kernel;
# - [ ] complete at least 70% of independent exercises;
# - [ ] score at least 80% on the phase assessment;
# - [ ] complete the lab before reading its solution;
# - [ ] produce the phase project and self-score it with the rubric;
# - [ ] name three failure modes you would watch for in real work.
