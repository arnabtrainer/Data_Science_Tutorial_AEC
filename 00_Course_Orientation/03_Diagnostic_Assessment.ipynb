# %% [markdown]
# # Entry Diagnostic Assessment
#
# This diagnostic selects a starting point. It is not a judgement of ability.
#
# Complete without external help. For each item, mark:
#
# - **0:** unfamiliar
# - **1:** recognize but cannot reproduce
# - **2:** can explain or implement with minor help
# - **3:** can apply and diagnose failures independently

# %% [markdown]
# ## Python and data
#
# 1. Explain variable binding and mutability in Python.
# 2. Write a function with validation, type hints, and tests.
# 3. Explain the difference between a NumPy view and copy.
# 4. Clean missing, duplicate, and invalid values without mutating raw data.
# 5. Explain Pandas join cardinality and validate a many-to-one merge.
#
# ## Statistics and EDA
#
# 6. Interpret a confidence interval without saying the parameter has a 95% probability of lying inside.
# 7. Explain a p-value and effect size.
# 8. Distinguish association, prediction, and causation.
# 9. Define row grain, target horizon, and feature cutoff.
# 10. Identify two types of target leakage.
#
# ## Machine learning
#
# 11. Explain why preprocessing must be fitted inside cross-validation.
# 12. Choose between accuracy, ROC-AUC, PR-AUC, recall, and calibration for a rare event.
# 13. Explain bias, variance, regularization, and learning curves.
# 14. Build a Scikit-learn preprocessing-and-model pipeline.
# 15. Choose a decision threshold under a capacity constraint.
#
# ## Advanced
#
# 16. Explain bagging versus boosting.
# 17. Explain why K-means depends on scale and cluster geometry.
# 18. Derive one gradient update for squared error.
# 19. Describe backpropagation and the purpose of train/eval modes.
# 20. Design monitoring for service, data, model, and decisions.

# %%
# Enter scores from 0 to 3.
scores = {
    "python_and_data": [0,0,0,0,0],
    "statistics_and_eda": [0,0,0,0,0],
    "machine_learning": [0,0,0,0,0],
    "advanced": [0,0,0,0,0],
}

totals = {section: sum(values) for section, values in scores.items()}
display(pd.Series(totals).to_frame("score_out_of_15"))
overall = sum(totals.values())
print("Overall:", overall, "/ 60")

# %% [markdown]
# ## Interpreting the diagnostic
#
# - **0–15:** Begin with Phase 1 and complete every foundation notebook.
# - **16–30:** Begin with Phase 1 or 2; use assessments to skip only demonstrated topics.
# - **31–45:** Review phase overviews and assessments, then begin at the first phase below 80%.
# - **46–54:** Use the practitioner/advanced notebooks, projects, and capstones.
# - **55–60:** Use the course as a rigorous revision and portfolio system; attempt projects before reading lessons.
#
# Even a high score does not justify skipping evaluation design, leakage, monitoring, or responsible-AI material.
