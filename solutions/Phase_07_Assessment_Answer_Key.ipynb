# %% [markdown]
# # Phase 7 Assessment — Answer Key
#
# **Phase:** Supervised Learning
# **Target score:** 80%
# **Recommended condition:** closed notebook, then verify and correct in a different colour or section.
#
# Use the model answers as rubrics. Alternative answers are valid when precise, justified, and consistent with the phase.

# %% [markdown]
# ## 1. Short answer
#
# **Question:** Define **least squares** in the context of **Simple Linear Regression from First Principles**, then state one assumption or limitation.
#
# **Model answer:** Parameter estimation by minimizing the sum of squared residuals. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 2. Short answer
#
# **Question:** Define **design matrix** in the context of **Multiple Regression and Diagnostics**, then state one assumption or limitation.
#
# **Model answer:** A core idea in Multiple Regression and Diagnostics; understand its definition, assumptions, operational role, and failure modes rather than memorizing its name. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 3. Short answer
#
# **Question:** Define **polynomial feature** in the context of **Polynomial Regression, Ridge, Lasso, and Elastic Net**, then state one assumption or limitation.
#
# **Model answer:** An input variable available at the decision point and defined consistently across training and inference. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 4. Short answer
#
# **Question:** Define **distance metric** in the context of **K-Nearest Neighbours**, then state one assumption or limitation.
#
# **Model answer:** A numerical summary whose usefulness depends on its decision context, population, and failure costs. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 5. Short answer
#
# **Question:** Define **logit** in the context of **Logistic Regression from First Principles**, then state one assumption or limitation.
#
# **Model answer:** An unnormalized class score; logits become probabilities after an appropriate link such as sigmoid or softmax. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 6. Short answer
#
# **Question:** Define **generative model** in the context of **Naive Bayes and Linear Discriminant Analysis**, then state one assumption or limitation.
#
# **Model answer:** A simplified mapping or probability representation learned or specified for a particular task. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 7. Short answer
#
# **Question:** Define **recursive partition** in the context of **Decision Trees and Pruning**, then state one assumption or limitation.
#
# **Model answer:** Repeatedly splitting feature space into regions with simpler target behaviour. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 8. Short answer
#
# **Question:** Define **bagging** in the context of **Random Forests and Extra Trees**, then state one assumption or limitation.
#
# **Model answer:** Fitting learners on perturbed samples and averaging them to reduce variance. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 9. Short answer
#
# **Question:** Define **boosting** in the context of **Gradient Boosting and XGBoost Concepts**, then state one assumption or limitation.
#
# **Model answer:** Building an additive predictor sequentially so each learner corrects current error. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 10. Short answer
#
# **Question:** Define **hyperplane** in the context of **Support Vector Machines and Kernels**, then state one assumption or limitation.
#
# **Model answer:** A core idea in Support Vector Machines and Kernels; understand its definition, assumptions, operational role, and failure modes rather than memorizing its name. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 11. Short answer
#
# **Question:** Define **hard voting** in the context of **Voting, Bagging, Boosting, and Stacking**, then state one assumption or limitation.
#
# **Model answer:** A core idea in Voting, Bagging, Boosting, and Stacking; understand its definition, assumptions, operational role, and failure modes rather than memorizing its name. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 12. Short answer
#
# **Question:** Define **global explanation** in the context of **Explainability: Importance, PDP, ICE, and SHAP Concepts**, then state one assumption or limitation.
#
# **Model answer:** A core idea in Explainability: Importance, PDP, ICE, and SHAP Concepts; understand its definition, assumptions, operational role, and failure modes rather than memorizing its name. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 13. Scenario
#
# **Question:** A result is unexpectedly perfect. What should you investigate first?
#
# **Model answer:** Investigate leakage, duplicate/identity overlap, target-derived features, evaluation code, and whether the split reproduces deployment.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 14. Scenario
#
# **Question:** A stakeholder requests the most advanced method immediately. How should you respond?
#
# **Model answer:** Clarify the decision and metric, establish a simple/current-process baseline, validate data and splits, then justify complexity only if it adds reliable value.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 15. Scenario
#
# **Question:** The overall metric is strong but one important subgroup performs poorly. What is required?
#
# **Model answer:** Report the slice, quantify uncertainty and harm, investigate data/label/process causes, consider thresholds or redesign, and define monitoring and governance.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 16. Scenario
#
# **Question:** A notebook runs only when cells are executed in a particular accidental order. What is wrong?
#
# **Model answer:** It depends on hidden state. Restart and run all; make dependencies explicit, initialize state, modularize logic, and add verification.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 17. Scenario
#
# **Question:** Which four categories of validity should be separated?
#
# **Model answer:** Calculation/software correctness, statistical validity, operational/train-serving validity, and decision/business validity.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 18. Scenario
#
# **Question:** When is a model output insufficient for a decision?
#
# **Model answer:** When costs, capacity, threshold, uncertainty, unsupported inputs, human review, or causal effect of the proposed action remain undefined.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 19. Scenario
#
# **Question:** Why must transformations be fitted inside validation folds?
#
# **Model answer:** To prevent validation information from influencing learned imputation, scaling, encoding, feature selection, or tuning.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## Score and remediation
#
# Classify each missed item:
#
# - **Vocabulary gap:** revisit the core vocabulary table.
# - **Mechanism gap:** recreate the worked example from scratch.
# - **Assumption gap:** write a counterexample and failure diagnostic.
# - **Transfer gap:** apply the idea to another bundled dataset.
# - **Communication gap:** practise the 30-second, 3-minute, and 15-minute explanation.
#
# Do not proceed merely because an answer looks familiar. Proceed when you can generate and defend it.
