# %% [markdown]
# # Phase 4 Assessment — Answer Key
#
# **Phase:** Statistics and Mathematics
# **Target score:** 80%
# **Recommended condition:** closed notebook, then verify and correct in a different colour or section.
#
# Use the model answers as rubrics. Alternative answers are valid when precise, justified, and consistent with the phase.

# %% [markdown]
# ## 1. Short answer
#
# **Question:** Define **population** in the context of **Descriptive Statistics and Robust Summaries**, then state one assumption or limitation.
#
# **Model answer:** The full set of entities or events about which an inference is intended. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 2. Short answer
#
# **Question:** Define **sample space** in the context of **Probability, Conditional Probability, and Bayes' Rule**, then state one assumption or limitation.
#
# **Model answer:** A core idea in Probability, Conditional Probability, and Bayes' Rule; understand its definition, assumptions, operational role, and failure modes rather than memorizing its name. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 3. Short answer
#
# **Question:** Define **random variable** in the context of **Random Variables and Probability Distributions**, then state one assumption or limitation.
#
# **Model answer:** A core idea in Random Variables and Probability Distributions; understand its definition, assumptions, operational role, and failure modes rather than memorizing its name. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 4. Short answer
#
# **Question:** Define **sampling frame** in the context of **Sampling, Law of Large Numbers, and Central Limit Theorem**, then state one assumption or limitation.
#
# **Model answer:** A core idea in Sampling, Law of Large Numbers, and Central Limit Theorem; understand its definition, assumptions, operational role, and failure modes rather than memorizing its name. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 5. Short answer
#
# **Question:** Define **confidence level** in the context of **Confidence Intervals and Hypothesis Testing**, then state one assumption or limitation.
#
# **Model answer:** The long-run coverage rate of an interval-construction procedure under its assumptions. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 6. Short answer
#
# **Question:** Define **one-sample t-test** in the context of **t-Tests, Chi-Square, ANOVA, and Nonparametric Tests**, then state one assumption or limitation.
#
# **Model answer:** A formal or executable procedure for checking a defined claim, contract, or behaviour under stated assumptions. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 7. Short answer
#
# **Question:** Define **covariance** in the context of **Covariance, Correlation, Confounding, and Causality**, then state one assumption or limitation.
#
# **Model answer:** A scale-dependent measure of how two variables vary together. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 8. Short answer
#
# **Question:** Define **scalar** in the context of **Linear Algebra for Machine Learning**, then state one assumption or limitation.
#
# **Model answer:** A core idea in Linear Algebra for Machine Learning; understand its definition, assumptions, operational role, and failure modes rather than memorizing its name. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 9. Short answer
#
# **Question:** Define **derivative** in the context of **Calculus, Gradients, and Optimization**, then state one assumption or limitation.
#
# **Model answer:** A core idea in Calculus, Gradients, and Optimization; understand its definition, assumptions, operational role, and failure modes rather than memorizing its name. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 10. Scenario
#
# **Question:** A result is unexpectedly perfect. What should you investigate first?
#
# **Model answer:** Investigate leakage, duplicate/identity overlap, target-derived features, evaluation code, and whether the split reproduces deployment.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 11. Scenario
#
# **Question:** A stakeholder requests the most advanced method immediately. How should you respond?
#
# **Model answer:** Clarify the decision and metric, establish a simple/current-process baseline, validate data and splits, then justify complexity only if it adds reliable value.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 12. Scenario
#
# **Question:** The overall metric is strong but one important subgroup performs poorly. What is required?
#
# **Model answer:** Report the slice, quantify uncertainty and harm, investigate data/label/process causes, consider thresholds or redesign, and define monitoring and governance.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 13. Scenario
#
# **Question:** A notebook runs only when cells are executed in a particular accidental order. What is wrong?
#
# **Model answer:** It depends on hidden state. Restart and run all; make dependencies explicit, initialize state, modularize logic, and add verification.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 14. Scenario
#
# **Question:** Which four categories of validity should be separated?
#
# **Model answer:** Calculation/software correctness, statistical validity, operational/train-serving validity, and decision/business validity.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 15. Scenario
#
# **Question:** When is a model output insufficient for a decision?
#
# **Model answer:** When costs, capacity, threshold, uncertainty, unsupported inputs, human review, or causal effect of the proposed action remain undefined.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 16. Scenario
#
# **Question:** Why must transformations be fitted inside validation folds?
#
# **Model answer:** To prevent validation information from influencing learned imputation, scaling, encoding, feature selection, or tuning.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## Score and remediation
#
# Classify each missed item:
#
# - **Vocabulary gap:** revisit the core vocabulary table.
# - **Mechanism gap:** recreate the worked example from scratch.
# - **Assumption gap:** write a counterexample and failure diagnostic.
# - **Transfer gap:** apply the idea to another bundled dataset.
# - **Communication gap:** practise the 30-second, 3-minute, and 15-minute explanation.
#
# Do not proceed merely because an answer looks familiar. Proceed when you can generate and defend it.
