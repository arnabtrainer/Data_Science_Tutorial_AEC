# %% [markdown]
# # Phase 6 Assessment — Answer Key
#
# **Phase:** Machine Learning Fundamentals
# **Target score:** 80%
# **Recommended condition:** closed notebook, then verify and correct in a different colour or section.
#
# Use the model answers as rubrics. Alternative answers are valid when precise, justified, and consistent with the phase.

# %% [markdown]
# ## 1. Short answer
#
# **Question:** Define **prediction task** in the context of **Problem Formulation and Baseline Models**, then state one assumption or limitation.
#
# **Model answer:** A core idea in Problem Formulation and Baseline Models; understand its definition, assumptions, operational role, and failure modes rather than memorizing its name. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 2. Short answer
#
# **Question:** Define **training set** in the context of **Train, Validation, Test, Group, and Time Splits**, then state one assumption or limitation.
#
# **Model answer:** Data used to estimate model parameters. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 3. Short answer
#
# **Question:** Define **imputation** in the context of **Imputation, Encoding, Scaling, and Feature Engineering**, then state one assumption or limitation.
#
# **Model answer:** Replacing missing values according to a rule learned from appropriate training data. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 4. Short answer
#
# **Question:** Define **estimator API** in the context of **Scikit-learn Estimators, Pipelines, and ColumnTransformer**, then state one assumption or limitation.
#
# **Model answer:** A core idea in Scikit-learn Estimators, Pipelines, and ColumnTransformer; understand its definition, assumptions, operational role, and failure modes rather than memorizing its name. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 5. Short answer
#
# **Question:** Define **MAE** in the context of **Regression and Classification Metrics**, then state one assumption or limitation.
#
# **Model answer:** Mean absolute error; an average error magnitude with linear penalty. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 6. Short answer
#
# **Question:** Define **underfitting** in the context of **Underfitting, Overfitting, Bias-Variance, and Regularization**, then state one assumption or limitation.
#
# **Model answer:** A core idea in Underfitting, Overfitting, Bias-Variance, and Regularization; understand its definition, assumptions, operational role, and failure modes rather than memorizing its name. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 7. Short answer
#
# **Question:** Define **k-fold** in the context of **Cross-Validation and Hyperparameter Search**, then state one assumption or limitation.
#
# **Model answer:** A core idea in Cross-Validation and Hyperparameter Search; understand its definition, assumptions, operational role, and failure modes rather than memorizing its name. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 8. Short answer
#
# **Question:** Define **class imbalance** in the context of **Imbalance, Thresholds, Calibration, and Error Analysis**, then state one assumption or limitation.
#
# **Model answer:** A core idea in Imbalance, Thresholds, Calibration, and Error Analysis; understand its definition, assumptions, operational role, and failure modes rather than memorizing its name. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 9. Scenario
#
# **Question:** A result is unexpectedly perfect. What should you investigate first?
#
# **Model answer:** Investigate leakage, duplicate/identity overlap, target-derived features, evaluation code, and whether the split reproduces deployment.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 10. Scenario
#
# **Question:** A stakeholder requests the most advanced method immediately. How should you respond?
#
# **Model answer:** Clarify the decision and metric, establish a simple/current-process baseline, validate data and splits, then justify complexity only if it adds reliable value.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 11. Scenario
#
# **Question:** The overall metric is strong but one important subgroup performs poorly. What is required?
#
# **Model answer:** Report the slice, quantify uncertainty and harm, investigate data/label/process causes, consider thresholds or redesign, and define monitoring and governance.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 12. Scenario
#
# **Question:** A notebook runs only when cells are executed in a particular accidental order. What is wrong?
#
# **Model answer:** It depends on hidden state. Restart and run all; make dependencies explicit, initialize state, modularize logic, and add verification.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 13. Scenario
#
# **Question:** Which four categories of validity should be separated?
#
# **Model answer:** Calculation/software correctness, statistical validity, operational/train-serving validity, and decision/business validity.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 14. Scenario
#
# **Question:** When is a model output insufficient for a decision?
#
# **Model answer:** When costs, capacity, threshold, uncertainty, unsupported inputs, human review, or causal effect of the proposed action remain undefined.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 15. Scenario
#
# **Question:** Why must transformations be fitted inside validation folds?
#
# **Model answer:** To prevent validation information from influencing learned imputation, scaling, encoding, feature selection, or tuning.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## Score and remediation
#
# Classify each missed item:
#
# - **Vocabulary gap:** revisit the core vocabulary table.
# - **Mechanism gap:** recreate the worked example from scratch.
# - **Assumption gap:** write a counterexample and failure diagnostic.
# - **Transfer gap:** apply the idea to another bundled dataset.
# - **Communication gap:** practise the 30-second, 3-minute, and 15-minute explanation.
#
# Do not proceed merely because an answer looks familiar. Proceed when you can generate and defend it.
