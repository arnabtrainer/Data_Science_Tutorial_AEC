# %% [markdown]
# # Phase 1 Assessment — Answer Key
#
# **Phase:** Python Foundation
# **Target score:** 80%
# **Recommended condition:** closed notebook, then verify and correct in a different colour or section.
#
# Use the model answers as rubrics. Alternative answers are valid when precise, justified, and consistent with the phase.

# %% [markdown]
# ## 1. Short answer
#
# **Question:** Define **Jupyter kernel** in the context of **Python, Jupyter, Variables, and Types**, then state one assumption or limitation.
#
# **Model answer:** The long-running Python process that owns variables, imports, and execution state for a notebook. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 2. Short answer
#
# **Question:** Define **string** in the context of **Strings and Core Collections**, then state one assumption or limitation.
#
# **Model answer:** An immutable Unicode sequence used for text. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 3. Short answer
#
# **Question:** Define **if/elif/else** in the context of **Control Flow and Iteration**, then state one assumption or limitation.
#
# **Model answer:** A core idea in Control Flow and Iteration; understand its definition, assumptions, operational role, and failure modes rather than memorizing its name. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 4. Short answer
#
# **Question:** Define **function contract** in the context of **Functions, Scope, and Comprehensions**, then state one assumption or limitation.
#
# **Model answer:** The accepted inputs, guaranteed outputs, side effects, errors, and invariants of a function. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 5. Short answer
#
# **Question:** Define **Path** in the context of **Files, Paths, CSV, and JSON**, then state one assumption or limitation.
#
# **Model answer:** An operating-system-independent object for constructing and manipulating filesystem paths. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 6. Short answer
#
# **Question:** Define **exception hierarchy** in the context of **Exceptions, Debugging, and Logging**, then state one assumption or limitation.
#
# **Model answer:** The inheritance tree used to classify and selectively handle errors. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 7. Short answer
#
# **Question:** Define **class** in the context of **Object-Oriented Design and Data Classes**, then state one assumption or limitation.
#
# **Model answer:** A core idea in Object-Oriented Design and Data Classes; understand its definition, assumptions, operational role, and failure modes rather than memorizing its name. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 8. Short answer
#
# **Question:** Define **iterable** in the context of **Iterators, Generators, Decorators, and Context Managers**, then state one assumption or limitation.
#
# **Model answer:** A core idea in Iterators, Generators, Decorators, and Context Managers; understand its definition, assumptions, operational role, and failure modes rather than memorizing its name. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 9. Short answer
#
# **Question:** Define **type hint** in the context of **Typing, Testing, Clean Code, and Packaging**, then state one assumption or limitation.
#
# **Model answer:** A core idea in Typing, Testing, Clean Code, and Packaging; understand its definition, assumptions, operational role, and failure modes rather than memorizing its name. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 10. Scenario
#
# **Question:** A result is unexpectedly perfect. What should you investigate first?
#
# **Model answer:** Investigate leakage, duplicate/identity overlap, target-derived features, evaluation code, and whether the split reproduces deployment.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 11. Scenario
#
# **Question:** A stakeholder requests the most advanced method immediately. How should you respond?
#
# **Model answer:** Clarify the decision and metric, establish a simple/current-process baseline, validate data and splits, then justify complexity only if it adds reliable value.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 12. Scenario
#
# **Question:** The overall metric is strong but one important subgroup performs poorly. What is required?
#
# **Model answer:** Report the slice, quantify uncertainty and harm, investigate data/label/process causes, consider thresholds or redesign, and define monitoring and governance.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 13. Scenario
#
# **Question:** A notebook runs only when cells are executed in a particular accidental order. What is wrong?
#
# **Model answer:** It depends on hidden state. Restart and run all; make dependencies explicit, initialize state, modularize logic, and add verification.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 14. Scenario
#
# **Question:** Which four categories of validity should be separated?
#
# **Model answer:** Calculation/software correctness, statistical validity, operational/train-serving validity, and decision/business validity.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 15. Scenario
#
# **Question:** When is a model output insufficient for a decision?
#
# **Model answer:** When costs, capacity, threshold, uncertainty, unsupported inputs, human review, or causal effect of the proposed action remain undefined.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 16. Scenario
#
# **Question:** Why must transformations be fitted inside validation folds?
#
# **Model answer:** To prevent validation information from influencing learned imputation, scaling, encoding, feature selection, or tuning.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## Score and remediation
#
# Classify each missed item:
#
# - **Vocabulary gap:** revisit the core vocabulary table.
# - **Mechanism gap:** recreate the worked example from scratch.
# - **Assumption gap:** write a counterexample and failure diagnostic.
# - **Transfer gap:** apply the idea to another bundled dataset.
# - **Communication gap:** practise the 30-second, 3-minute, and 15-minute explanation.
#
# Do not proceed merely because an answer looks familiar. Proceed when you can generate and defend it.
