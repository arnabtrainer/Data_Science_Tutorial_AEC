# %% [markdown]
# # Phase 9 Assessment — Answer Key
#
# **Phase:** Deep Learning
# **Target score:** 80%
# **Recommended condition:** closed notebook, then verify and correct in a different colour or section.
#
# Use the model answers as rubrics. Alternative answers are valid when precise, justified, and consistent with the phase.

# %% [markdown]
# ## 1. Short answer
#
# **Question:** Define **tensor** in the context of **PyTorch Tensors, Devices, and Autograd**, then state one assumption or limitation.
#
# **Model answer:** A multidimensional numerical array used by deep-learning frameworks. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 2. Short answer
#
# **Question:** Define **neuron** in the context of **Neurons, Activations, Outputs, and Losses**, then state one assumption or limitation.
#
# **Model answer:** A core idea in Neurons, Activations, Outputs, and Losses; understand its definition, assumptions, operational role, and failure modes rather than memorizing its name. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 3. Short answer
#
# **Question:** Define **forward pass** in the context of **Backpropagation from First Principles**, then state one assumption or limitation.
#
# **Model answer:** A core idea in Backpropagation from First Principles; understand its definition, assumptions, operational role, and failure modes rather than memorizing its name. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 4. Short answer
#
# **Question:** Define **Dataset** in the context of **Datasets, DataLoaders, Training Loops, and Optimizers**, then state one assumption or limitation.
#
# **Model answer:** A core idea in Datasets, DataLoaders, Training Loops, and Optimizers; understand its definition, assumptions, operational role, and failure modes rather than memorizing its name. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 5. Short answer
#
# **Question:** Define **multilayer perceptron** in the context of **Feed-Forward Networks for Tabular Data**, then state one assumption or limitation.
#
# **Model answer:** A feed-forward network composed of affine layers and nonlinear activations. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 6. Short answer
#
# **Question:** Define **weight initialization** in the context of **Initialization, Normalization, Dropout, Schedules, and Early Stopping**, then state one assumption or limitation.
#
# **Model answer:** A core idea in Initialization, Normalization, Dropout, Schedules, and Early Stopping; understand its definition, assumptions, operational role, and failure modes rather than memorizing its name. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 7. Short answer
#
# **Question:** Define **convolution** in the context of **Convolutional Neural Networks**, then state one assumption or limitation.
#
# **Model answer:** A spatially shared local weighted operation used to detect patterns across positions. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 8. Short answer
#
# **Question:** Define **pretraining** in the context of **Transfer Learning and Fine-Tuning**, then state one assumption or limitation.
#
# **Model answer:** A core idea in Transfer Learning and Fine-Tuning; understand its definition, assumptions, operational role, and failure modes rather than memorizing its name. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 9. Short answer
#
# **Question:** Define **sequence** in the context of **RNNs, LSTMs, and GRUs**, then state one assumption or limitation.
#
# **Model answer:** A core idea in RNNs, LSTMs, and GRUs; understand its definition, assumptions, operational role, and failure modes rather than memorizing its name. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 10. Short answer
#
# **Question:** Define **query** in the context of **Attention from First Principles**, then state one assumption or limitation.
#
# **Model answer:** A vector representing what a token or position is seeking. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 11. Short answer
#
# **Question:** Define **tokenization** in the context of **Transformer Encoders and Text Classification**, then state one assumption or limitation.
#
# **Model answer:** A core idea in Transformer Encoders and Text Classification; understand its definition, assumptions, operational role, and failure modes rather than memorizing its name. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 12. Short answer
#
# **Question:** Define **shape invariant** in the context of **Deep-Learning Debugging, Evaluation, Reproducibility, and Serving**, then state one assumption or limitation.
#
# **Model answer:** A core idea in Deep-Learning Debugging, Evaluation, Reproducibility, and Serving; understand its definition, assumptions, operational role, and failure modes rather than memorizing its name. A complete answer should also name an assumption/limitation from the lesson rather than treating the concept as universally valid.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 13. Scenario
#
# **Question:** A result is unexpectedly perfect. What should you investigate first?
#
# **Model answer:** Investigate leakage, duplicate/identity overlap, target-derived features, evaluation code, and whether the split reproduces deployment.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 14. Scenario
#
# **Question:** A stakeholder requests the most advanced method immediately. How should you respond?
#
# **Model answer:** Clarify the decision and metric, establish a simple/current-process baseline, validate data and splits, then justify complexity only if it adds reliable value.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 15. Scenario
#
# **Question:** The overall metric is strong but one important subgroup performs poorly. What is required?
#
# **Model answer:** Report the slice, quantify uncertainty and harm, investigate data/label/process causes, consider thresholds or redesign, and define monitoring and governance.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 16. Scenario
#
# **Question:** A notebook runs only when cells are executed in a particular accidental order. What is wrong?
#
# **Model answer:** It depends on hidden state. Restart and run all; make dependencies explicit, initialize state, modularize logic, and add verification.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 17. Scenario
#
# **Question:** Which four categories of validity should be separated?
#
# **Model answer:** Calculation/software correctness, statistical validity, operational/train-serving validity, and decision/business validity.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 18. Scenario
#
# **Question:** When is a model output insufficient for a decision?
#
# **Model answer:** When costs, capacity, threshold, uncertainty, unsupported inputs, human review, or causal effect of the proposed action remain undefined.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## 19. Scenario
#
# **Question:** Why must transformations be fitted inside validation folds?
#
# **Model answer:** To prevent validation information from influencing learned imputation, scaling, encoding, feature selection, or tuning.
#
# **Scoring:** 0 = absent/incorrect; 1 = partial definition; 2 = correct mechanism; 3 = mechanism plus assumption/limitation and applied interpretation.

# %% [markdown]
# ## Score and remediation
#
# Classify each missed item:
#
# - **Vocabulary gap:** revisit the core vocabulary table.
# - **Mechanism gap:** recreate the worked example from scratch.
# - **Assumption gap:** write a counterexample and failure diagnostic.
# - **Transfer gap:** apply the idea to another bundled dataset.
# - **Communication gap:** practise the 30-second, 3-minute, and 15-minute explanation.
#
# Do not proceed merely because an answer looks familiar. Proceed when you can generate and defend it.
