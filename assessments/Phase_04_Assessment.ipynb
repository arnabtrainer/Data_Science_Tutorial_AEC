# %% [markdown]
# # Phase 4 Assessment
#
# **Phase:** Statistics and Mathematics
# **Target score:** 80%
# **Recommended condition:** closed notebook, then verify and correct in a different colour or section.
#
# Answer every item before opening the answer key. For short answers, include mechanism, assumption, and one practical example.

# %% [markdown]
# ## 1. Short answer
#
# Define **population** in the context of **Descriptive Statistics and Robust Summaries**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 2. Short answer
#
# Define **sample space** in the context of **Probability, Conditional Probability, and Bayes' Rule**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 3. Short answer
#
# Define **random variable** in the context of **Random Variables and Probability Distributions**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 4. Short answer
#
# Define **sampling frame** in the context of **Sampling, Law of Large Numbers, and Central Limit Theorem**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 5. Short answer
#
# Define **confidence level** in the context of **Confidence Intervals and Hypothesis Testing**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 6. Short answer
#
# Define **one-sample t-test** in the context of **t-Tests, Chi-Square, ANOVA, and Nonparametric Tests**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 7. Short answer
#
# Define **covariance** in the context of **Covariance, Correlation, Confounding, and Causality**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 8. Short answer
#
# Define **scalar** in the context of **Linear Algebra for Machine Learning**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 9. Short answer
#
# Define **derivative** in the context of **Calculus, Gradients, and Optimization**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 10. Scenario
#
# A result is unexpectedly perfect. What should you investigate first?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 11. Scenario
#
# A stakeholder requests the most advanced method immediately. How should you respond?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 12. Scenario
#
# The overall metric is strong but one important subgroup performs poorly. What is required?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 13. Scenario
#
# A notebook runs only when cells are executed in a particular accidental order. What is wrong?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 14. Scenario
#
# Which four categories of validity should be separated?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 15. Scenario
#
# When is a model output insufficient for a decision?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 16. Scenario
#
# Why must transformations be fitted inside validation folds?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## Score and remediation
#
# Classify each missed item:
#
# - **Vocabulary gap:** revisit the core vocabulary table.
# - **Mechanism gap:** recreate the worked example from scratch.
# - **Assumption gap:** write a counterexample and failure diagnostic.
# - **Transfer gap:** apply the idea to another bundled dataset.
# - **Communication gap:** practise the 30-second, 3-minute, and 15-minute explanation.
#
# Do not proceed merely because an answer looks familiar. Proceed when you can generate and defend it.
