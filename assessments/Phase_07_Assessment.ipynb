# %% [markdown]
# # Phase 7 Assessment
#
# **Phase:** Supervised Learning
# **Target score:** 80%
# **Recommended condition:** closed notebook, then verify and correct in a different colour or section.
#
# Answer every item before opening the answer key. For short answers, include mechanism, assumption, and one practical example.

# %% [markdown]
# ## 1. Short answer
#
# Define **least squares** in the context of **Simple Linear Regression from First Principles**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 2. Short answer
#
# Define **design matrix** in the context of **Multiple Regression and Diagnostics**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 3. Short answer
#
# Define **polynomial feature** in the context of **Polynomial Regression, Ridge, Lasso, and Elastic Net**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 4. Short answer
#
# Define **distance metric** in the context of **K-Nearest Neighbours**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 5. Short answer
#
# Define **logit** in the context of **Logistic Regression from First Principles**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 6. Short answer
#
# Define **generative model** in the context of **Naive Bayes and Linear Discriminant Analysis**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 7. Short answer
#
# Define **recursive partition** in the context of **Decision Trees and Pruning**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 8. Short answer
#
# Define **bagging** in the context of **Random Forests and Extra Trees**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 9. Short answer
#
# Define **boosting** in the context of **Gradient Boosting and XGBoost Concepts**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 10. Short answer
#
# Define **hyperplane** in the context of **Support Vector Machines and Kernels**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 11. Short answer
#
# Define **hard voting** in the context of **Voting, Bagging, Boosting, and Stacking**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 12. Short answer
#
# Define **global explanation** in the context of **Explainability: Importance, PDP, ICE, and SHAP Concepts**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 13. Scenario
#
# A result is unexpectedly perfect. What should you investigate first?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 14. Scenario
#
# A stakeholder requests the most advanced method immediately. How should you respond?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 15. Scenario
#
# The overall metric is strong but one important subgroup performs poorly. What is required?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 16. Scenario
#
# A notebook runs only when cells are executed in a particular accidental order. What is wrong?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 17. Scenario
#
# Which four categories of validity should be separated?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 18. Scenario
#
# When is a model output insufficient for a decision?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 19. Scenario
#
# Why must transformations be fitted inside validation folds?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## Score and remediation
#
# Classify each missed item:
#
# - **Vocabulary gap:** revisit the core vocabulary table.
# - **Mechanism gap:** recreate the worked example from scratch.
# - **Assumption gap:** write a counterexample and failure diagnostic.
# - **Transfer gap:** apply the idea to another bundled dataset.
# - **Communication gap:** practise the 30-second, 3-minute, and 15-minute explanation.
#
# Do not proceed merely because an answer looks familiar. Proceed when you can generate and defend it.
