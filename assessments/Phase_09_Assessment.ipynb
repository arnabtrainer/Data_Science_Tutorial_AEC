# %% [markdown]
# # Phase 9 Assessment
#
# **Phase:** Deep Learning
# **Target score:** 80%
# **Recommended condition:** closed notebook, then verify and correct in a different colour or section.
#
# Answer every item before opening the answer key. For short answers, include mechanism, assumption, and one practical example.

# %% [markdown]
# ## 1. Short answer
#
# Define **tensor** in the context of **PyTorch Tensors, Devices, and Autograd**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 2. Short answer
#
# Define **neuron** in the context of **Neurons, Activations, Outputs, and Losses**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 3. Short answer
#
# Define **forward pass** in the context of **Backpropagation from First Principles**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 4. Short answer
#
# Define **Dataset** in the context of **Datasets, DataLoaders, Training Loops, and Optimizers**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 5. Short answer
#
# Define **multilayer perceptron** in the context of **Feed-Forward Networks for Tabular Data**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 6. Short answer
#
# Define **weight initialization** in the context of **Initialization, Normalization, Dropout, Schedules, and Early Stopping**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 7. Short answer
#
# Define **convolution** in the context of **Convolutional Neural Networks**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 8. Short answer
#
# Define **pretraining** in the context of **Transfer Learning and Fine-Tuning**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 9. Short answer
#
# Define **sequence** in the context of **RNNs, LSTMs, and GRUs**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 10. Short answer
#
# Define **query** in the context of **Attention from First Principles**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 11. Short answer
#
# Define **tokenization** in the context of **Transformer Encoders and Text Classification**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 12. Short answer
#
# Define **shape invariant** in the context of **Deep-Learning Debugging, Evaluation, Reproducibility, and Serving**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 13. Scenario
#
# A result is unexpectedly perfect. What should you investigate first?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 14. Scenario
#
# A stakeholder requests the most advanced method immediately. How should you respond?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 15. Scenario
#
# The overall metric is strong but one important subgroup performs poorly. What is required?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 16. Scenario
#
# A notebook runs only when cells are executed in a particular accidental order. What is wrong?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 17. Scenario
#
# Which four categories of validity should be separated?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 18. Scenario
#
# When is a model output insufficient for a decision?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 19. Scenario
#
# Why must transformations be fitted inside validation folds?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## Score and remediation
#
# Classify each missed item:
#
# - **Vocabulary gap:** revisit the core vocabulary table.
# - **Mechanism gap:** recreate the worked example from scratch.
# - **Assumption gap:** write a counterexample and failure diagnostic.
# - **Transfer gap:** apply the idea to another bundled dataset.
# - **Communication gap:** practise the 30-second, 3-minute, and 15-minute explanation.
#
# Do not proceed merely because an answer looks familiar. Proceed when you can generate and defend it.
