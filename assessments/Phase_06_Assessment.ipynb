# %% [markdown]
# # Phase 6 Assessment
#
# **Phase:** Machine Learning Fundamentals
# **Target score:** 80%
# **Recommended condition:** closed notebook, then verify and correct in a different colour or section.
#
# Answer every item before opening the answer key. For short answers, include mechanism, assumption, and one practical example.

# %% [markdown]
# ## 1. Short answer
#
# Define **prediction task** in the context of **Problem Formulation and Baseline Models**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 2. Short answer
#
# Define **training set** in the context of **Train, Validation, Test, Group, and Time Splits**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 3. Short answer
#
# Define **imputation** in the context of **Imputation, Encoding, Scaling, and Feature Engineering**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 4. Short answer
#
# Define **estimator API** in the context of **Scikit-learn Estimators, Pipelines, and ColumnTransformer**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 5. Short answer
#
# Define **MAE** in the context of **Regression and Classification Metrics**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 6. Short answer
#
# Define **underfitting** in the context of **Underfitting, Overfitting, Bias-Variance, and Regularization**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 7. Short answer
#
# Define **k-fold** in the context of **Cross-Validation and Hyperparameter Search**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 8. Short answer
#
# Define **class imbalance** in the context of **Imbalance, Thresholds, Calibration, and Error Analysis**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 9. Scenario
#
# A result is unexpectedly perfect. What should you investigate first?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 10. Scenario
#
# A stakeholder requests the most advanced method immediately. How should you respond?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 11. Scenario
#
# The overall metric is strong but one important subgroup performs poorly. What is required?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 12. Scenario
#
# A notebook runs only when cells are executed in a particular accidental order. What is wrong?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 13. Scenario
#
# Which four categories of validity should be separated?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 14. Scenario
#
# When is a model output insufficient for a decision?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 15. Scenario
#
# Why must transformations be fitted inside validation folds?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## Score and remediation
#
# Classify each missed item:
#
# - **Vocabulary gap:** revisit the core vocabulary table.
# - **Mechanism gap:** recreate the worked example from scratch.
# - **Assumption gap:** write a counterexample and failure diagnostic.
# - **Transfer gap:** apply the idea to another bundled dataset.
# - **Communication gap:** practise the 30-second, 3-minute, and 15-minute explanation.
#
# Do not proceed merely because an answer looks familiar. Proceed when you can generate and defend it.
