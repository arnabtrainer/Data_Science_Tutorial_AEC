# %% [markdown]
# # Phase 10 Assessment
#
# **Phase:** Real-World ML and MLOps
# **Target score:** 80%
# **Recommended condition:** closed notebook, then verify and correct in a different colour or section.
#
# Answer every item before opening the answer key. For short answers, include mechanism, assumption, and one practical example.

# %% [markdown]
# ## 1. Short answer
#
# Define **source package** in the context of **Production Project Structure, Configuration, Logging, and Typing**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 2. Short answer
#
# Define **data contract** in the context of **Data Contracts, Validation, and Testing Strategy**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 3. Short answer
#
# Define **experiment run** in the context of **Experiment Tracking, Reproducibility, and Model Registry**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 4. Short answer
#
# Define **serialization** in the context of **Serialization, Batch Inference, and Feature Parity**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 5. Short answer
#
# Define **REST API** in the context of **FastAPI Model Serving and API Design**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 6. Short answer
#
# Define **container image** in the context of **Containers, CI/CD, and Release Safety**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 7. Short answer
#
# Define **batch inference** in the context of **Deployment Patterns and AWS-Oriented Architecture**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 8. Short answer
#
# Define **service-level indicator** in the context of **Monitoring, Drift, Incidents, and Retraining**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 9. Short answer
#
# Define **fairness metric** in the context of **Responsible AI, Privacy, Security, and Governance**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 10. Short answer
#
# Define **system boundary** in the context of **End-to-End ML System Design**, then state one assumption or limitation.
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 11. Scenario
#
# A result is unexpectedly perfect. What should you investigate first?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 12. Scenario
#
# A stakeholder requests the most advanced method immediately. How should you respond?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 13. Scenario
#
# The overall metric is strong but one important subgroup performs poorly. What is required?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 14. Scenario
#
# A notebook runs only when cells are executed in a particular accidental order. What is wrong?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 15. Scenario
#
# Which four categories of validity should be separated?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 16. Scenario
#
# When is a model output insufficient for a decision?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## 17. Scenario
#
# Why must transformations be fitted inside validation folds?
#
# **Your answer:**
#
#
# **Confidence (1–5):**

# %% [markdown]
# ## Score and remediation
#
# Classify each missed item:
#
# - **Vocabulary gap:** revisit the core vocabulary table.
# - **Mechanism gap:** recreate the worked example from scratch.
# - **Assumption gap:** write a counterexample and failure diagnostic.
# - **Transfer gap:** apply the idea to another bundled dataset.
# - **Communication gap:** practise the 30-second, 3-minute, and 15-minute explanation.
#
# Do not proceed merely because an answer looks familiar. Proceed when you can generate and defend it.
