# %% [markdown]
# # Phase 10: Real-World ML and MLOps
#
# ## Phase goal
#
# Turn experiments into governed, tested, observable, deployable decision systems.
#
# **Estimated lesson time:** 23.5 hours
# **Recommended additional practice:** 16 hours
# **Prerequisite:** Ability to build and evaluate a complete ML model; basic command-line familiarity is useful.
#
# This phase progresses from conceptual foundations to practitioner execution and advanced failure analysis. Complete lessons in order unless a diagnostic assessment shows that you already satisfy the readiness criteria.

# %% [markdown]
# ## Phase learning outcomes
#
# After completing this phase, you should be able to:
#
# 1. Explain every central concept without relying on library vocabulary alone.
# 2. Implement the core mechanisms in small, testable examples.
# 3. Select methods according to assumptions, constraints, and decision cost.
# 4. Detect common correctness, leakage, interpretation, and operational failures.
# 5. Complete the phase lab without copying the reference solution.
# 6. Produce the phase project with evidence, tests, limitations, and a professional handoff.

# %% [markdown]
# ## Notebook sequence
#
#         | # | Notebook | Level | Suggested time | Purpose |
#         |---:|---|---|---:|---|
#         | 01 | [Production Project Structure, Configuration, Logging, and Typing](01_Production_Project_Structure_Configuration_Logging_and_Typing.ipynb) | Practitioner | 120 min | Separate exploration from reusable code and establish configuration, interfaces, observability, and dependency boundaries. |
# | 02 | [Data Contracts, Validation, and Testing Strategy](02_Data_Contracts_Validation_and_Testing_Strategy.ipynb) | Practitioner | 130 min | Enforce schemas and invariants at boundaries with unit, integration, contract, data, and end-to-end tests. |
# | 03 | [Experiment Tracking, Reproducibility, and Model Registry](03_Experiment_Tracking_Reproducibility_and_Model_Registry.ipynb) | Advanced | 125 min | Record code, data, configuration, metrics, artifacts, lineage, and approval status so results can be reproduced and governed. |
# | 04 | [Serialization, Batch Inference, and Feature Parity](04_Serialization_Batch_Inference_and_Feature_Parity.ipynb) | Advanced | 130 min | Persist complete pipelines, version schemas, test compatibility, and keep training and serving transformations identical. |
# | 05 | [FastAPI Model Serving and API Design](05_FastAPI_Model_Serving_and_API_Design.ipynb) | Advanced | 145 min | Design typed inference endpoints with health checks, validation, error semantics, versioning, timeouts, and safe model lifecycle. |
# | 06 | [Containers, CI/CD, and Release Safety](06_Containers_CI_CD_and_Release_Safety.ipynb) | Advanced | 140 min | Build immutable images, automate tests and scans, promote artifacts, and retain rollback through staged delivery. |
# | 07 | [Deployment Patterns and AWS-Oriented Architecture](07_Deployment_Patterns_and_AWS_Oriented_Architecture.ipynb) | Advanced | 145 min | Choose batch, synchronous, asynchronous, or streaming inference and map reliability requirements to cloud components. |
# | 08 | [Monitoring, Drift, Incidents, and Retraining](08_Monitoring_Drift_Incidents_and_Retraining.ipynb) | Advanced | 155 min | Observe service, data, model, and decision layers; detect drift; collect outcomes; and trigger review rather than blind retraining. |
# | 09 | [Responsible AI, Privacy, Security, and Governance](09_Responsible_AI_Privacy_Security_and_Governance.ipynb) | Advanced | 155 min | Assess fairness, harm, explainability, consent, minimization, access, adversarial risk, review, and auditability across the lifecycle. |
# | 10 | [End-to-End ML System Design](10_End_to_End_ML_System_Design.ipynb) | Advanced | 165 min | Integrate problem framing, data, experimentation, release, serving, monitoring, feedback, ownership, and decommissioning. |
#
#         ### Dependency path
#
#         1. **Production Project Structure, Configuration, Logging, and Typing** — builds the concepts needed for **Data Contracts, Validation, and Testing Strategy**.
# 2. **Data Contracts, Validation, and Testing Strategy** — builds the concepts needed for **Experiment Tracking, Reproducibility, and Model Registry**.
# 3. **Experiment Tracking, Reproducibility, and Model Registry** — builds the concepts needed for **Serialization, Batch Inference, and Feature Parity**.
# 4. **Serialization, Batch Inference, and Feature Parity** — builds the concepts needed for **FastAPI Model Serving and API Design**.
# 5. **FastAPI Model Serving and API Design** — builds the concepts needed for **Containers, CI/CD, and Release Safety**.
# 6. **Containers, CI/CD, and Release Safety** — builds the concepts needed for **Deployment Patterns and AWS-Oriented Architecture**.
# 7. **Deployment Patterns and AWS-Oriented Architecture** — builds the concepts needed for **Monitoring, Drift, Incidents, and Retraining**.
# 8. **Monitoring, Drift, Incidents, and Retraining** — builds the concepts needed for **Responsible AI, Privacy, Security, and Governance**.
# 9. **Responsible AI, Privacy, Security, and Governance** — builds the concepts needed for **End-to-End ML System Design**.
# 10. **End-to-End ML System Design** — builds the concepts needed for the phase lab and project.

# %% [markdown]
# ## How to study this phase
#
# Use a three-pass method:
#
# ### Pass 1 — Understand
# Read the mental model, vocabulary, and formal lens. Run the example only after predicting its result.
#
# ### Pass 2 — Reconstruct
# Close the example and recreate the mechanism in a fresh cell or file. Use assertions and edge cases.
#
# ### Pass 3 — Transfer
# Apply the method to a bundled dataset or a new scenario. Explain assumptions, limitations, and decision impact.
#
# A suggested cadence is **five hours per week for approximately 5 week(s)** for the core lessons, followed by the lab, assessment, and project.

# %% [markdown]
# ## Phase lab
#
#         **Scenario:** A churn model must move from experiment to a safe, observable API with repeatable releases.
#
#         **Deliverable:** A package, artifact, API contract, tests, container, rollout plan, monitoring specification, and model card.
#
#         Required work:
#
#         - Move feature and training logic into importable modules.
# - Validate training and inference schemas.
# - Train and version a complete preprocessing pipeline.
# - Test feature order, edge cases, and serialization parity.
# - Define typed API requests/responses and health endpoints.
# - Design CI/CD, canary, rollback, and ownership.
# - Define service/data/model/decision monitoring and governance.
#
#         Files:
#
#         - `../exercises/Phase_10_Lab.ipynb`
#         - `../solutions/Phase_10_Lab_Solution.ipynb`
#         - `../assessments/Phase_10_Assessment.ipynb`

# %% [markdown]
# ## Phase project
#
# **Production Churn Service**
#
# Package, test, serve, containerize, monitor, and govern an end-to-end churn prediction service.
#
# The formal project brief is in:
#
# `../projects/Phase_10_Production_Churn_Service.ipynb`
#
# ### Minimum professional standard
#
# - reproducible environment and random state;
# - explicit input/output contracts;
# - tests or validation assertions;
# - clear assumptions and excluded uses;
# - evidence-backed conclusions;
# - limitations and risk register;
# - README-style run instructions;
# - no hidden notebook state.

# %% [markdown]
# ## Readiness checkpoint
#
# Proceed to the next phase only when you can:
#
# - [ ] explain the phase goal and how each lesson contributes;
# - [ ] run every required notebook from a clean kernel;
# - [ ] complete at least 70% of independent exercises;
# - [ ] score at least 80% on the phase assessment;
# - [ ] complete the lab before reading its solution;
# - [ ] produce the phase project and self-score it with the rubric;
# - [ ] name three failure modes you would watch for in real work.
