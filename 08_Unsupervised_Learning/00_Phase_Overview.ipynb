# %% [markdown]
# # Phase 8: Unsupervised Learning
#
# ## Phase goal
#
# Discover structure, representations, and anomalies without pretending that unlabeled patterns are automatically meaningful.
#
# **Estimated lesson time:** 16.5 hours
# **Recommended additional practice:** 11 hours
# **Prerequisite:** Feature scaling, distance intuition, validation, and exploratory analysis.
#
# This phase progresses from conceptual foundations to practitioner execution and advanced failure analysis. Complete lessons in order unless a diagnostic assessment shows that you already satisfy the readiness criteria.

# %% [markdown]
# ## Phase learning outcomes
#
# After completing this phase, you should be able to:
#
# 1. Explain every central concept without relying on library vocabulary alone.
# 2. Implement the core mechanisms in small, testable examples.
# 3. Select methods according to assumptions, constraints, and decision cost.
# 4. Detect common correctness, leakage, interpretation, and operational failures.
# 5. Complete the phase lab without copying the reference solution.
# 6. Produce the phase project with evidence, tests, limitations, and a professional handoff.

# %% [markdown]
# ## Notebook sequence
#
#         | # | Notebook | Level | Suggested time | Purpose |
#         |---:|---|---|---:|---|
#         | 01 | [Distance, Scaling, and Cluster Validation](01_Distance_Scaling_and_Cluster_Validation.ipynb) | Foundation | 105 min | Understand why unsupervised results depend on representation, distance, scale, and an explicit purpose. |
# | 02 | [K-Means from First Principles](02_K_Means_from_First_Principles.ipynb) | Practitioner | 130 min | Derive assignment and centroid-update steps, initialization, convergence, inertia, and shape assumptions. |
# | 03 | [Hierarchical Clustering and DBSCAN](03_Hierarchical_Clustering_and_DBSCAN.ipynb) | Practitioner | 130 min | Compare nested agglomeration with density connectivity and understand dendrogram, linkage, epsilon, and noise. |
# | 04 | [Gaussian Mixture Models and Soft Clustering](04_Gaussian_Mixture_Models_and_Soft_Clustering.ipynb) | Advanced | 125 min | Model data as a weighted mixture of probability distributions and estimate latent membership with EM. |
# | 05 | [Principal Component Analysis from First Principles](05_Principal_Component_Analysis_from_First_Principles.ipynb) | Practitioner | 140 min | Find orthogonal directions of maximum variance, project data, and understand scaling, reconstruction, and interpretability. |
# | 06 | [t-SNE and UMAP Concepts](06_t_SNE_and_UMAP_Concepts.ipynb) | Advanced | 115 min | Use nonlinear embeddings for local-neighbourhood exploration without treating plot distances, cluster sizes, or axes as ground truth. |
# | 07 | [Anomaly Detection](07_Anomaly_Detection.ipynb) | Advanced | 135 min | Define anomalies relative to context, compare statistical and isolation methods, and evaluate with sparse labels and asymmetric costs. |
# | 08 | [Association Rules and Market-Basket Analysis](08_Association_Rules_and_Market_Basket_Analysis.ipynb) | Practitioner | 110 min | Discover co-occurrence rules while controlling for popularity, multiple testing, and actionability. |
#
#         ### Dependency path
#
#         1. **Distance, Scaling, and Cluster Validation** — builds the concepts needed for **K-Means from First Principles**.
# 2. **K-Means from First Principles** — builds the concepts needed for **Hierarchical Clustering and DBSCAN**.
# 3. **Hierarchical Clustering and DBSCAN** — builds the concepts needed for **Gaussian Mixture Models and Soft Clustering**.
# 4. **Gaussian Mixture Models and Soft Clustering** — builds the concepts needed for **Principal Component Analysis from First Principles**.
# 5. **Principal Component Analysis from First Principles** — builds the concepts needed for **t-SNE and UMAP Concepts**.
# 6. **t-SNE and UMAP Concepts** — builds the concepts needed for **Anomaly Detection**.
# 7. **Anomaly Detection** — builds the concepts needed for **Association Rules and Market-Basket Analysis**.
# 8. **Association Rules and Market-Basket Analysis** — builds the concepts needed for the phase lab and project.

# %% [markdown]
# ## How to study this phase
#
# Use a three-pass method:
#
# ### Pass 1 — Understand
# Read the mental model, vocabulary, and formal lens. Run the example only after predicting its result.
#
# ### Pass 2 — Reconstruct
# Close the example and recreate the mechanism in a fresh cell or file. Use assertions and edge cases.
#
# ### Pass 3 — Transfer
# Apply the method to a bundled dataset or a new scenario. Explain assumptions, limitations, and decision impact.
#
# A suggested cadence is **five hours per week for approximately 4 week(s)** for the core lessons, followed by the lab, assessment, and project.

# %% [markdown]
# ## Phase lab
#
#         **Scenario:** A business wants actionable customer segments and an operations team wants a low-noise anomaly queue.
#
#         **Deliverable:** Validated segmentation profiles and anomaly rankings with stability, sensitivity, and actionability analysis.
#
#         Required work:
#
#         - Justify features, transformations, distance, and scaling.
# - Compare K-means, hierarchical, density, and mixture approaches.
# - Evaluate stability across seeds and resamples.
# - Profile clusters without using identifiers as features.
# - Compare statistical and Isolation Forest anomaly scores.
# - Evaluate alerts under a finite review budget.
# - Document why outputs are hypotheses rather than discovered truth.
#
#         Files:
#
#         - `../exercises/Phase_08_Lab.ipynb`
#         - `../solutions/Phase_08_Lab_Solution.ipynb`
#         - `../assessments/Phase_08_Assessment.ipynb`

# %% [markdown]
# ## Phase project
#
# **Segmentation and Anomaly Investigation**
#
# Compare clustering and anomaly methods, validate stability, profile outputs, and translate them into usable actions.
#
# The formal project brief is in:
#
# `../projects/Phase_08_Segmentation_and_Anomaly_Investigation.ipynb`
#
# ### Minimum professional standard
#
# - reproducible environment and random state;
# - explicit input/output contracts;
# - tests or validation assertions;
# - clear assumptions and excluded uses;
# - evidence-backed conclusions;
# - limitations and risk register;
# - README-style run instructions;
# - no hidden notebook state.

# %% [markdown]
# ## Readiness checkpoint
#
# Proceed to the next phase only when you can:
#
# - [ ] explain the phase goal and how each lesson contributes;
# - [ ] run every required notebook from a clean kernel;
# - [ ] complete at least 70% of independent exercises;
# - [ ] score at least 80% on the phase assessment;
# - [ ] complete the lab before reading its solution;
# - [ ] produce the phase project and self-score it with the rubric;
# - [ ] name three failure modes you would watch for in real work.
