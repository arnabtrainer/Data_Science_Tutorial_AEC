# %% [markdown]
# # Start Here
#
# This is the entry point for the complete Data Science, Machine Learning, Deep Learning, and MLOps course.
#
# ## First session
#
# 1. Read `README.md`.
# 2. Open `00_Course_Orientation/00_Welcome_and_Master_Roadmap.ipynb`.
# 3. Run `00_Course_Orientation/01_Environment_Setup_and_Verification.ipynb`.
# 4. Complete `00_Course_Orientation/03_Diagnostic_Assessment.ipynb`.
# 5. Select a schedule from `reference/STUDY_PLANS.md`.
# 6. Begin `01_Python_Foundation/00_Phase_Overview.ipynb`.
#
# ## Course rule
#
# Predict → execute → explain → vary → test → transfer.
#
# A green code cell is not the finish line. You should be able to reconstruct, validate, and defend the result.

# %%
from pathlib import Path
import sys
import json
import warnings
warnings.filterwarnings("ignore")

_candidates = [Path.cwd(), *Path.cwd().parents]
COURSE_ROOT = next((p for p in _candidates if (p / "datasets").exists()), Path.cwd())
DATA_DIR = COURSE_ROOT / "datasets"
ARTIFACT_DIR = COURSE_ROOT / "artifacts"
ARTIFACT_DIR.mkdir(exist_ok=True)
sys.path.insert(0, str(COURSE_ROOT))

import numpy as np
import pandas as pd
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt
from IPython.display import display

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
print(f"Course root: {COURSE_ROOT}")

# %%
phase_overviews = sorted(COURSE_ROOT.glob("[0-9][0-9]_*/*Phase_Overview.ipynb"))
print("Found phase overviews:", len(phase_overviews))
for path in phase_overviews:
    print("-", path.relative_to(COURSE_ROOT))
